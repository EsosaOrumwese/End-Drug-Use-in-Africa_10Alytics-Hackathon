# %% [markdown]
# # Tackling the Health Crises in Africa
# People dying from lack of medical resources
# ## Introduction
# The lack of access to adequate medical resources and facilities have led to the significant number of deaths. Some of these deaths could have been avoided by timely access to a medical professional or close proximity of hospitals.
#
# Health systems across Africa are underfunded and understaffed. Less than half of African citizens (52%) about 615 million people have access to the health care they need, the quality of health services across the continent is generally poor, and family planning needs of half the continent’s women and girls are unmet.
#
# **Let’s focus on Africa in this dataset**
#
# You are required to provide solutions to the health challenges, especially in Africa. Ensure that you allow all your creative self to shine through and remember, Africa looks up to you for a solution.

# %% [markdown]
# ## Data Wrangling

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %matplotlib inline

# %%
os.listdir('./data')
# Out:
# ['1. annual-number-of-deaths-by-cause.csv',
#  '2. number-of-deaths-by-age-group.csv',
#  '3. Medical Doctors Per 10000 population.xlsx',
#  '4. ISO 3166_country-and-continent-codes-list-csv.csv',
#  '5. World Population.csv',
#  '6. Current health expenditure (% of GDP).xlsx',
#  'World Healthcaredata.xlsx']

# %% [markdown]
# ### Assessment

# %%
causesofDeath_df = pd.read_csv('./data/1. annual-number-of-deaths-by-cause.csv')

# %%
causesofDeath_df
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#       Meningitis  Alzheimer's disease and other dementias  \
# 0         2933.0                                   1402.0
# 1         2731.0                                   1424.0
# 2         2460.0                                   1449.0
# 3         2327.0                                   1508.0
# 4         2254.0                                   1544.0
# ...          ...                                      ...
# 7268      1439.0                                    754.0
# 7269      1457.0                                    767.0
# 7270      1460.0                                    781.0
# 7271      1450.0                                    795.0
# 7272      1450.0                                    812.0
#
#       Parkinson's disease  Nutritional deficiencies  Malaria  Drowning  ...  \
# 0                   450.0                    2488.0    393.0    2127.0  ...
# 1                   455.0                    2277.0    255.0    1973.0  ...
# 2                   460.0                    2040.0    239.0    1852.0  ...
# 3                   473.0                    1846.0    390.0    1775.0  ...
# 4                   482.0                    1705.0     94.0    1716.0  ...
# ...                   ...                       ...      ...       ...  ...
# 7268                215.0                    3019.0   2518.0     770.0  ...
# 7269                219.0                    3056.0   2050.0     801.0  ...
# 7270                223.0                    2990.0   2116.0     818.0  ...
# 7271                227.0                    2918.0   2088.0     825.0  ...
# 7272                232.0                    2884.0   2068.0     827.0  ...
#
#       Chronic kidney disease  Poisonings  Protein  Terrorism (deaths)  \
# 0                     4490.0       512.0   2439.0              1199.0
# 1                     4534.0       495.0   2231.0              1092.0
# 2                     4597.0       483.0   1998.0              1065.0
# 3                     4785.0       483.0   1805.0              1525.0
# 4                     4846.0       482.0   1667.0              3521.0
# ...                      ...         ...      ...                 ...
# 7268                  2108.0       381.0   2990.0                 NaN
# 7269                  2160.0       393.0   3027.0                 NaN
# 7270                  2196.0       398.0   2962.0                 0.0
# 7271                  2240.0       400.0   2890.0                 NaN
# 7272                  2292.0       405.0   2855.0                 NaN
#
#       Road injuries  Chronic respiratory diseases  \
# 0            7425.0                        7222.0
# 1            7355.0                        7143.0
# 2            7290.0                        7045.0
# 3            7432.0                        6916.0
# 4            7494.0                        6878.0
# ...             ...                           ...
# 7268         2373.0                        2751.0
# 7269         2436.0                        2788.0
# 7270         2473.0                        2818.0
# 7271         2509.0                        2849.0
# 7272         2554.0                        2891.0
#
#       Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                         3346.0              6458.0
# 1                                         3316.0              6408.0
# 2                                         3291.0              6358.0
# 3                                         3318.0              6370.0
# 4                                         3353.0              6398.0
# ...                                          ...                 ...
# 7268                                      1956.0              4202.0
# 7269                                      1962.0              4264.0
# 7270                                      2007.0              4342.0
# 7271                                      2030.0              4377.0
# 7272                                      2065.0              4437.0
#
#       Fire, heat, and hot substances  Acute hepatitis
# 0                              481.0           3437.0
# 1                              462.0           3005.0
# 2                              448.0           2663.0
# 3                              448.0           2365.0
# 4                              445.0           2264.0
# ...                              ...              ...
# 7268                           632.0            146.0
# 7269                           648.0            146.0
# 7270                           654.0            144.0
# 7271                           657.0            139.0
# 7272                           662.0            136.0
#
# [7273 rows x 36 columns]

# %%
causesofDeath_df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Number of executions (Amnesty International)', 'Meningitis',
#        'Alzheimer's disease and other dementias', 'Parkinson's disease',
#        'Nutritional deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal violence', 'Maternal disorders', 'HIV/AIDS',
#        'Drug use disorders', 'Tuberculosis', 'Cardiovascular diseases',
#        'Lower respiratory infections', 'Neonatal disorders',
#        'Alcohol use disorders', 'Self', 'Exposure to forces of nature',
#        'Diarrheal diseases', 'Environmental heat and cold exposure',
#        'Neoplasms', 'Conflict and terrorism', 'Diabetes mellitus',
#        'Chronic kidney disease', 'Poisonings', 'Protein', 'Terrorism (deaths)',
#        'Road injuries', 'Chronic respiratory diseases',
#        'Cirrhosis and other chronic liver diseases', 'Digestive diseases',
#        'Fire, heat, and hot substances', 'Acute hepatitis'],
#       dtype='object')

# %%
ageGroupDeaths_df = pd.read_csv("./data/2. number-of-deaths-by-age-group.csv")

# %%
ageGroupDeaths_df
# Out:
#            Entity Code  Year  Deaths 70+ years  Deaths 50-69 years  \
# 0     Afghanistan  AFG  1990             34681               40624
# 1     Afghanistan  AFG  1991             35271               41414
# 2     Afghanistan  AFG  1992             35694               41829
# 3     Afghanistan  AFG  1993             36433               42598
# 4     Afghanistan  AFG  1994             37460               43923
# ...           ...  ...   ...               ...                 ...
# 6835     Zimbabwe  ZWE  2015             25573               32963
# 6836     Zimbabwe  ZWE  2016             25804               33138
# 6837     Zimbabwe  ZWE  2017             26030               33282
# 6838     Zimbabwe  ZWE  2018             26279               33316
# 6839     Zimbabwe  ZWE  2019             26666               33816
#
#       Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 0                       22968               5642           78170
# 1                       26523               6433           83035
# 2                       30000               6854           93859
# 3                       32339               7206          106537
# 4                       36817               8106          115334
# ...                       ...                ...             ...
# 6835                    43441               4506           26551
# 6836                    42011               4592           25499
# 6837                    40417               4737           24766
# 6838                    38536               4430           23905
# 6839                    38193               4282           23566
#
# [6840 rows x 8 columns]

# %%
doctorsPerPopulation_df = pd.read_excel('./data/3. Medical Doctors Per 10000 population.xlsx',
                                        header=2)

# %%
doctorsPerPopulation_df
# Out:
#       IndicatorCode                                     Indicator  \
# 0          HWF_0001                  Medical doctors (per 10,000)
# 1          HWF_0001                  Medical doctors (per 10,000)
# 2          HWF_0001                  Medical doctors (per 10,000)
# 3          HWF_0001                  Medical doctors (per 10,000)
# 4          HWF_0001                  Medical doctors (per 10,000)
# ...             ...                                           ...
# 11503      HWF_0005  Medical doctors not further defined (number)
# 11504      HWF_0005  Medical doctors not further defined (number)
# 11505      HWF_0005  Medical doctors not further defined (number)
# 11506      HWF_0005  Medical doctors not further defined (number)
# 11507      HWF_0005  Medical doctors not further defined (number)
#
#       ParentLocationCode   ParentLocation ThreeLocCode Location  Period  \
# 0                    AFR           Africa          AGO   Angola    2018
# 1                    AFR           Africa          AGO   Angola    2017
# 2                    AFR           Africa          AGO   Angola    2009
# 3                    AFR           Africa          AGO   Angola    2004
# 4                    AFR           Africa          AGO   Angola    1997
# ...                  ...              ...          ...      ...     ...
# 11503                WPR  Western Pacific          WSM    Samoa    2010
# 11504                WPR  Western Pacific          WSM    Samoa    2008
# 11505                WPR  Western Pacific          WSM    Samoa    2005
# 11506                WPR  Western Pacific          WSM    Samoa    2003
# 11507                WPR  Western Pacific          WSM    Samoa    1999
#
#        FactValueNumeric Value
# 0                  2.14  2.14
# 1                  2.15  2.15
# 2                  1.31  1.31
# 3                  0.62  0.62
# 4                  0.59  0.59
# ...                 ...   ...
# 11503             64.00    64
# 11504             85.00    85
# 11505             50.00    50
# 11506             50.00    50
# 11507            120.00   120
#
# [11508 rows x 9 columns]

# %%
doctorsPerPopulation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11508 entries, 0 to 11507
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   IndicatorCode       11508 non-null  object
#  1   Indicator           11508 non-null  object
#  2   ParentLocationCode  11508 non-null  object
#  3   ParentLocation      11508 non-null  object
#  4   ThreeLocCode        11508 non-null  object
#  5   Location            11508 non-null  object
#  6   Period              11508 non-null  int64
#  7   FactValueNumeric    11508 non-null  float64
#  8   Value               11508 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 809.3+ KB

# %%
# let's find out the values that made 'Value' an object type
objectType = []

for i in doctorsPerPopulation_df.Value:
      try:
            float(i)
      except:
            objectType.append(i)

# %%
len(objectType)
# Out:
# 4488

# %%
# converting to Series so that we can take a sample
objectType = pd.Series(objectType)
set(objectType.sample(10))
# Out:
# {'107\xa0374',
#  '11\xa0818',
#  '133\xa0984',
#  '13\xa0268',
#  '145\xa0413',
#  '175\xa0912',
#  '21\xa0051',
#  '243\xa0008',
#  '26\xa0171',
#  '54\xa0208'}

# %% [markdown]
# Looks like some values have a whitespace character (`\xa0`)

# %%
doctorsPerPopulation_df.Value.sample(7)
# Out:
# 2871         857
# 8224     169 108
# 7241      15 132
# 10772     28 708
# 2805        9.46
# 1414       20.31
# 10383       1047
# Name: Value, dtype: object

# %%
doctorsPerPopulation_df.isna().sum()
# Out:
# IndicatorCode         0
# Indicator             0
# ParentLocationCode    0
# ParentLocation        0
# ThreeLocCode          0
# Location              0
# Period                0
# FactValueNumeric      0
# Value                 0
# dtype: int64

# %%
countryCodes_df = pd.read_csv('./data/4. ISO 3166_country-and-continent-codes-list-csv.csv')

# %%
countryCodes_df
# Out:
#     Continent_Name Continent_Code  \
# 0             Asia             AS
# 1           Europe             EU
# 2       Antarctica             AN
# 3           Africa             AF
# 4          Oceania             OC
# ..             ...            ...
# 249         Africa             AF
# 250        Oceania             OC
# 251           Asia             AS
# 252           Asia             AS
# 253           Asia             AS
#
#                                      Country_Name Two_Letter_Country_Code  \
# 0                Afghanistan, Islamic Republic of                      AF
# 1                            Albania, Republic of                      AL
# 2    Antarctica (the territory South of 60 deg S)                      AQ
# 3        Algeria, People's Democratic Republic of                      DZ
# 4                                  American Samoa                      AS
# ..                                            ...                     ...
# 249                           Zambia, Republic of                      ZM
# 250                            Disputed Territory                      XX
# 251                Iraq-Saudi Arabia Neutral Zone                      XE
# 252                   United Nations Neutral Zone                      XD
# 253                               Spratly Islands                      XS
#
#     Three_Letter_Country_Code  Country_Number
# 0                         AFG             4.0
# 1                         ALB             8.0
# 2                         ATA            10.0
# 3                         DZA            12.0
# 4                         ASM            16.0
# ..                        ...             ...
# 249                       ZMB           894.0
# 250                        XX             NaN
# 251                        XE             NaN
# 252                        XD             NaN
# 253                        XS             NaN
#
# [254 rows x 6 columns]

# %%
population = pd.read_csv('./data/5. World Population.csv')

# %%
population
# Out:
#             Entity Code   Year  Population (historical estimates)
# 0      Afghanistan  AFG -10000                              14737
# 1      Afghanistan  AFG  -9000                              20405
# 2      Afghanistan  AFG  -8000                              28253
# 3      Afghanistan  AFG  -7000                              39120
# 4      Afghanistan  AFG  -6000                              54166
# ...            ...  ...    ...                                ...
# 56908     Zimbabwe  ZWE   2017                           14751101
# 56909     Zimbabwe  ZWE   2018                           15052191
# 56910     Zimbabwe  ZWE   2019                           15354606
# 56911     Zimbabwe  ZWE   2020                           15669663
# 56912     Zimbabwe  ZWE   2021                           15993525
#
# [56913 rows x 4 columns]

# %%
population.isna().sum()
# Out:
# Entity                                  0
# Code                                 2662
# Year                                    0
# Population (historical estimates)       0
# dtype: int64

# %%
population[population['Code'].isna()]
# Out:
#                               Entity Code   Year  \
# 259                           Africa  NaN -10000
# 260                           Africa  NaN  -9000
# 261                           Africa  NaN  -8000
# 262                           Africa  NaN  -7000
# 263                           Africa  NaN  -6000
# ...                              ...  ...    ...
# 54176  Upper-middle-income countries  NaN   2017
# 54177  Upper-middle-income countries  NaN   2018
# 54178  Upper-middle-income countries  NaN   2019
# 54179  Upper-middle-income countries  NaN   2020
# 54180  Upper-middle-income countries  NaN   2021
#
#        Population (historical estimates)
# 259                               227636
# 260                               323059
# 261                               462991
# 262                               670044
# 263                               979129
# ...                                  ...
# 54176                         2500616723
# 54177                         2516785800
# 54178                         2530546049
# 54179                         2541463877
# 54180                         2548718303
#
# [2662 rows x 4 columns]

# %%
population[population['Code'].isna()].Entity.value_counts()
# Out:
# Africa                           259
# Asia                             259
# Europe                           259
# High-income countries            259
# Low-income countries             259
# Lower-middle-income countries    259
# North America                    259
# Oceania                          259
# South America                    259
# Upper-middle-income countries    259
# Saint Barthlemy                   72
# Name: Entity, dtype: int64

# %%
healthExpenditure = pd.read_excel('./data/6. Current health expenditure (% of GDP).xlsx',
                                  header=4)

# %%
healthExpenditure
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name      2000      2001      2002  \
# 0    Current health expenditure (% of GDP)       NaN       NaN       NaN
# 1    Current health expenditure (% of GDP)  6.252428  6.390627  5.969416
# 2    Current health expenditure (% of GDP)       NaN       NaN  9.443390
# 3    Current health expenditure (% of GDP)  3.771302  3.770256  3.387634
# 4    Current health expenditure (% of GDP)  1.908599  4.483516  3.329461
# ..                                     ...       ...       ...       ...
# 261  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 262  Current health expenditure (% of GDP)  4.666065  4.945151  4.832372
# 263  Current health expenditure (% of GDP)  8.164721  7.939017  7.464463
# 264  Current health expenditure (% of GDP)  7.152371  6.552485  6.794035
# 265  Current health expenditure (% of GDP)       NaN       NaN       NaN
#
#          2003      2004      2005       2006  ...      2012      2013  \
# 0         NaN       NaN       NaN        NaN  ...       NaN       NaN
# 1    6.635666  6.710734  6.528098   6.492506  ...  6.562794  6.565689
# 2    8.941258  9.808474  9.948290  10.622766  ...  7.897176  8.805941
# 3    4.681099  4.481882  4.277262   4.139578  ...  3.505065  3.621925
# 4    3.547973  3.967201  2.852197   2.685537  ...  2.395750  2.732828
# ..        ...       ...       ...        ...  ...       ...       ...
# 261       NaN       NaN       NaN        NaN  ...       NaN       NaN
# 262  5.757578  5.514405  5.205854   5.529299  ...  5.195936  4.960832
# 263  7.915304  7.764534  7.689974   7.692216  ...  8.773108  8.855524
# 264  7.189994  7.049950  6.863322   5.873673  ...  3.930529  4.690910
# 265       NaN       NaN       NaN        NaN  ...  6.918354  7.110148
#
#          2014       2015       2016       2017       2018       2019  2020  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 1    6.152063   6.482263   6.390654   6.317654   6.286829   6.266386   NaN
# 2    9.528871  10.105348  11.818562  12.620817  14.126743  13.242202   NaN
# 3    3.614749   3.834676   3.811248   3.789624   3.393160   3.366100   NaN
# 4    2.434129   2.605795   2.713149   2.791503   2.540102   2.533360   NaN
# ..        ...        ...        ...        ...        ...        ...   ...
# 261       NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 262  4.841805   4.252858        NaN        NaN        NaN        NaN   NaN
# 263  8.550915   8.790190   8.821429   8.722624   8.858297   9.109355   NaN
# 264  3.829242   4.435102   4.477207   4.376977   5.032715   5.312203   NaN
# 265  8.133525   7.452066   7.675163   7.469752   8.680062   7.703565   NaN
#
#      2021
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 261   NaN
# 262   NaN
# 263   NaN
# 264   NaN
# 265   NaN
#
# [266 rows x 25 columns]

# %%
healthExpenditure.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# 2000               34
# 2001               34
# 2002               33
# 2003               31
# 2004               31
# 2005               31
# 2006               31
# 2007               31
# 2008               31
# 2009               31
# 2010               30
# 2011               29
# 2012               30
# 2013               31
# 2014               31
# 2015               31
# 2016               32
# 2017               31
# 2018               31
# 2019               32
# 2020              266
# 2021              266
# dtype: int64

# %%
healthExpenditure['Indicator Name'].value_counts()
# Out:
# Current health expenditure (% of GDP)    266
# Name: Indicator Name, dtype: int64

# %% [markdown]
# 2020 and 2021 are both empty.

# %% [markdown]
# **Issues**:
#
# `countryCodes_df`
# * Split by `,` for the `Country_Name` column
#
# `causesofDeath_df`
# * ~~Create a subset of only African countries~~
# * Create a column for 'Causes' and another for 'Case Count' using `.melt()`
# * Drop unrelated death causes
#
# `ageGroupDeaths_df`
# * ~~Create a subset of only African countries~~
# * Create a column for 'Age Range' and another for 'Death Count' using `.melt()`
#
# `doctorsPerPopulation_df`
# * ~~Create subset of only African countries~~
# * Remove white space character (`\xa0`) from `Value` column
# * Replace wrong 'Location's
#
# `healthExpenditure`
# * ~~Create subset of African countries~~
# * Drop 'Indicator Name'
# * Create a column for 'Year' and 'Health Expenditure (% of GDP)' for values using `.melt()`
# * Replace wrong 'Country Name's

# %% [markdown]
# ### Cleaning

# %%
causesofDeath_df_copy = causesofDeath_df.copy()
ageGroupDeaths_df_copy = ageGroupDeaths_df.copy()
doctorsPerPopulation_df_copy = doctorsPerPopulation_df.copy()
countryCodes_df_copy = countryCodes_df.copy()
healthExpenditure_copy = healthExpenditure.copy()

# %% [markdown]
# #### `countryCodes_df`
# * Split by `,` for the `Country_Name` column

# %%
countryCodes_df_copy
# Out:
#     Continent_Name Continent_Code  \
# 0             Asia             AS
# 1           Europe             EU
# 2       Antarctica             AN
# 3           Africa             AF
# 4          Oceania             OC
# ..             ...            ...
# 249         Africa             AF
# 250        Oceania             OC
# 251           Asia             AS
# 252           Asia             AS
# 253           Asia             AS
#
#                                      Country_Name Two_Letter_Country_Code  \
# 0                Afghanistan, Islamic Republic of                      AF
# 1                            Albania, Republic of                      AL
# 2    Antarctica (the territory South of 60 deg S)                      AQ
# 3        Algeria, People's Democratic Republic of                      DZ
# 4                                  American Samoa                      AS
# ..                                            ...                     ...
# 249                           Zambia, Republic of                      ZM
# 250                            Disputed Territory                      XX
# 251                Iraq-Saudi Arabia Neutral Zone                      XE
# 252                   United Nations Neutral Zone                      XD
# 253                               Spratly Islands                      XS
#
#     Three_Letter_Country_Code  Country_Number
# 0                         AFG             4.0
# 1                         ALB             8.0
# 2                         ATA            10.0
# 3                         DZA            12.0
# 4                         ASM            16.0
# ..                        ...             ...
# 249                       ZMB           894.0
# 250                        XX             NaN
# 251                        XE             NaN
# 252                        XD             NaN
# 253                        XS             NaN
#
# [254 rows x 6 columns]

# %%
countryCodes_df_copy['Country_Name'] = countryCodes_df_copy['Country_Name'].apply(lambda x: x.split(',')[0])

# %%
countryCodes_df_copy.Country_Name.sample(15)
# Out:
# 2      Antarctica (the territory South of 60 deg S)
# 236                                        Guernsey
# 87                                           Greece
# 147                                         Namibia
# 184                                         Romania
# 135                                      Martinique
# 17                                          Belgium
# 249                                          Zambia
# 200                                      Seychelles
# 57                                   Czech Republic
# 73                                    Åland Islands
# 242                                    Burkina Faso
# 221                                            Togo
# 165                        Northern Mariana Islands
# 6                                            Angola
# Name: Country_Name, dtype: object

# %% [markdown]
# Let's get the subset for African countries

# %%
countryCodes_df_copy.Continent_Name.unique()
# Out:
# array(['Asia', 'Europe', 'Antarctica', 'Africa', 'Oceania',
#        'North America', 'South America'], dtype=object)

# %%
africanCountries = countryCodes_df_copy.query('Continent_Name == "Africa"')
africanCountries = africanCountries.reset_index(drop=True)

# %%
africanCountries
# Out:
#    Continent_Name Continent_Code              Country_Name  \
# 0          Africa             AF                   Algeria
# 1          Africa             AF                    Angola
# 2          Africa             AF                  Botswana
# 3          Africa             AF                   Burundi
# 4          Africa             AF                  Cameroon
# 5          Africa             AF                Cape Verde
# 6          Africa             AF  Central African Republic
# 7          Africa             AF                      Chad
# 8          Africa             AF                   Comoros
# 9          Africa             AF                   Mayotte
# 10         Africa             AF                     Congo
# 11         Africa             AF                     Congo
# 12         Africa             AF                     Benin
# 13         Africa             AF         Equatorial Guinea
# 14         Africa             AF                  Ethiopia
# 15         Africa             AF                   Eritrea
# 16         Africa             AF                  Djibouti
# 17         Africa             AF                     Gabon
# 18         Africa             AF                    Gambia
# 19         Africa             AF                     Ghana
# 20         Africa             AF                    Guinea
# 21         Africa             AF             Cote d'Ivoire
# 22         Africa             AF                     Kenya
# 23         Africa             AF                   Lesotho
# 24         Africa             AF                   Liberia
# 25         Africa             AF    Libyan Arab Jamahiriya
# 26         Africa             AF                Madagascar
# 27         Africa             AF                    Malawi
# 28         Africa             AF                      Mali
# 29         Africa             AF                Mauritania
# 30         Africa             AF                 Mauritius
# 31         Africa             AF                   Morocco
# 32         Africa             AF                Mozambique
# 33         Africa             AF                   Namibia
# 34         Africa             AF                     Niger
# 35         Africa             AF                   Nigeria
# 36         Africa             AF             Guinea-Bissau
# 37         Africa             AF                   Reunion
# 38         Africa             AF                    Rwanda
# 39         Africa             AF              Saint Helena
# 40         Africa             AF     Sao Tome and Principe
# 41         Africa             AF                   Senegal
# 42         Africa             AF                Seychelles
# 43         Africa             AF              Sierra Leone
# 44         Africa             AF                   Somalia
# 45         Africa             AF              South Africa
# 46         Africa             AF                  Zimbabwe
# 47         Africa             AF               South Sudan
# 48         Africa             AF            Western Sahara
# 49         Africa             AF                     Sudan
# 50         Africa             AF                 Swaziland
# 51         Africa             AF                      Togo
# 52         Africa             AF                   Tunisia
# 53         Africa             AF                    Uganda
# 54         Africa             AF                     Egypt
# 55         Africa             AF                  Tanzania
# 56         Africa             AF              Burkina Faso
# 57         Africa             AF                    Zambia
#
#    Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number
# 0                       DZ                       DZA            12.0
# 1                       AO                       AGO            24.0
# 2                       BW                       BWA            72.0
# 3                       BI                       BDI           108.0
# 4                       CM                       CMR           120.0
# 5                       CV                       CPV           132.0
# 6                       CF                       CAF           140.0
# 7                       TD                       TCD           148.0
# 8                       KM                       COM           174.0
# 9                       YT                       MYT           175.0
# 10                      CG                       COG           178.0
# 11                      CD                       COD           180.0
# 12                      BJ                       BEN           204.0
# 13                      GQ                       GNQ           226.0
# 14                      ET                       ETH           231.0
# 15                      ER                       ERI           232.0
# 16                      DJ                       DJI           262.0
# 17                      GA                       GAB           266.0
# 18                      GM                       GMB           270.0
# 19                      GH                       GHA           288.0
# 20                      GN                       GIN           324.0
# 21                      CI                       CIV           384.0
# 22                      KE                       KEN           404.0
# 23                      LS                       LSO           426.0
# 24                      LR                       LBR           430.0
# 25                      LY                       LBY           434.0
# 26                      MG                       MDG           450.0
# 27                      MW                       MWI           454.0
# 28                      ML                       MLI           466.0
# 29                      MR                       MRT           478.0
# 30                      MU                       MUS           480.0
# 31                      MA                       MAR           504.0
# 32                      MZ                       MOZ           508.0
# 33                     NaN                       NAM           516.0
# 34                      NE                       NER           562.0
# 35                      NG                       NGA           566.0
# 36                      GW                       GNB           624.0
# 37                      RE                       REU           638.0
# 38                      RW                       RWA           646.0
# 39                      SH                       SHN           654.0
# 40                      ST                       STP           678.0
# 41                      SN                       SEN           686.0
# 42                      SC                       SYC           690.0
# 43                      SL                       SLE           694.0
# 44                      SO                       SOM           706.0
# 45                      ZA                       ZAF           710.0
# 46                      ZW                       ZWE           716.0
# 47                      SS                       SSD           728.0
# 48                      EH                       ESH           732.0
# 49                      SD                       SDN           736.0
# 50                      SZ                       SWZ           748.0
# 51                      TG                       TGO           768.0
# 52                      TN                       TUN           788.0
# 53                      UG                       UGA           800.0
# 54                      EG                       EGY           818.0
# 55                      TZ                       TZA           834.0
# 56                      BF                       BFA           854.0
# 57                      ZM                       ZMB           894.0

# %% [markdown]
# Convert Namibia's country code from NaN to 'NA'

# %%
africanCountries[africanCountries['Two_Letter_Country_Code'].isna()]
# Out:
#    Continent_Name Continent_Code Country_Name Two_Letter_Country_Code  \
# 33         Africa             AF      Namibia                     NaN
#
#    Three_Letter_Country_Code  Country_Number
# 33                       NAM           516.0

# %%
countryCodes_df_copy[countryCodes_df_copy['Two_Letter_Country_Code'].isna()]
# Out:
#     Continent_Name Continent_Code Country_Name Two_Letter_Country_Code  \
# 147         Africa             AF      Namibia                     NaN
#
#     Three_Letter_Country_Code  Country_Number
# 147                       NAM           516.0

# %%
africanCountries.iloc[33,3] = 'NA'
countryCodes_df_copy.iloc[147,3] = 'NA'

# %% [markdown]
# Looks like there are two Congos. The Democratic Republic of Congo (COD) and the Republic of Congo (COG). Let's convert change the name for COD only.

# %%
congoIndex = africanCountries.query('Three_Letter_Country_Code == "COD"').index
worldcongoIndex = countryCodes_df_copy.query('Three_Letter_Country_Code == "COD"').index

africanCountries.iloc[congoIndex,2] = 'Democratic Republic of Congo'
countryCodes_df_copy.iloc[worldcongoIndex,2] = 'Democratic Republic of Congo'

# %% [markdown]
# #### `causesofDeath_df`
# * ~~Create a subset of only African countries~~
# * Create a column for 'Causes' and another for 'Case Count' using `.melt()`
# * Drop unrelated death causes

# %%
causesofDeath_df_copy
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#       Meningitis  Alzheimer's disease and other dementias  \
# 0         2933.0                                   1402.0
# 1         2731.0                                   1424.0
# 2         2460.0                                   1449.0
# 3         2327.0                                   1508.0
# 4         2254.0                                   1544.0
# ...          ...                                      ...
# 7268      1439.0                                    754.0
# 7269      1457.0                                    767.0
# 7270      1460.0                                    781.0
# 7271      1450.0                                    795.0
# 7272      1450.0                                    812.0
#
#       Parkinson's disease  Nutritional deficiencies  Malaria  Drowning  ...  \
# 0                   450.0                    2488.0    393.0    2127.0  ...
# 1                   455.0                    2277.0    255.0    1973.0  ...
# 2                   460.0                    2040.0    239.0    1852.0  ...
# 3                   473.0                    1846.0    390.0    1775.0  ...
# 4                   482.0                    1705.0     94.0    1716.0  ...
# ...                   ...                       ...      ...       ...  ...
# 7268                215.0                    3019.0   2518.0     770.0  ...
# 7269                219.0                    3056.0   2050.0     801.0  ...
# 7270                223.0                    2990.0   2116.0     818.0  ...
# 7271                227.0                    2918.0   2088.0     825.0  ...
# 7272                232.0                    2884.0   2068.0     827.0  ...
#
#       Chronic kidney disease  Poisonings  Protein  Terrorism (deaths)  \
# 0                     4490.0       512.0   2439.0              1199.0
# 1                     4534.0       495.0   2231.0              1092.0
# 2                     4597.0       483.0   1998.0              1065.0
# 3                     4785.0       483.0   1805.0              1525.0
# 4                     4846.0       482.0   1667.0              3521.0
# ...                      ...         ...      ...                 ...
# 7268                  2108.0       381.0   2990.0                 NaN
# 7269                  2160.0       393.0   3027.0                 NaN
# 7270                  2196.0       398.0   2962.0                 0.0
# 7271                  2240.0       400.0   2890.0                 NaN
# 7272                  2292.0       405.0   2855.0                 NaN
#
#       Road injuries  Chronic respiratory diseases  \
# 0            7425.0                        7222.0
# 1            7355.0                        7143.0
# 2            7290.0                        7045.0
# 3            7432.0                        6916.0
# 4            7494.0                        6878.0
# ...             ...                           ...
# 7268         2373.0                        2751.0
# 7269         2436.0                        2788.0
# 7270         2473.0                        2818.0
# 7271         2509.0                        2849.0
# 7272         2554.0                        2891.0
#
#       Cirrhosis and other chronic liver diseases  Digestive diseases  \
# 0                                         3346.0              6458.0
# 1                                         3316.0              6408.0
# 2                                         3291.0              6358.0
# 3                                         3318.0              6370.0
# 4                                         3353.0              6398.0
# ...                                          ...                 ...
# 7268                                      1956.0              4202.0
# 7269                                      1962.0              4264.0
# 7270                                      2007.0              4342.0
# 7271                                      2030.0              4377.0
# 7272                                      2065.0              4437.0
#
#       Fire, heat, and hot substances  Acute hepatitis
# 0                              481.0           3437.0
# 1                              462.0           3005.0
# 2                              448.0           2663.0
# 3                              448.0           2365.0
# 4                              445.0           2264.0
# ...                              ...              ...
# 7268                           632.0            146.0
# 7269                           648.0            146.0
# 7270                           654.0            144.0
# 7271                           657.0            139.0
# 7272                           662.0            136.0
#
# [7273 rows x 36 columns]

# %%
# creating a subset of african countries
#african_three_letter_code = africanCountries.Three_Letter_Country_Code

#causesofDeath_df_copy = causesofDeath_df_copy.query('Code in @african_three_letter_code')

# %%
causesofDeath_df_copy.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Meningitis  Alzheimer's disease and other dementias  Parkinson's disease  \
# 0      2933.0                                   1402.0                450.0
# 1      2731.0                                   1424.0                455.0
# 2      2460.0                                   1449.0                460.0
# 3      2327.0                                   1508.0                473.0
# 4      2254.0                                   1544.0                482.0
#
#    Nutritional deficiencies  Malaria  Drowning  ...  Chronic kidney disease  \
# 0                    2488.0    393.0    2127.0  ...                  4490.0
# 1                    2277.0    255.0    1973.0  ...                  4534.0
# 2                    2040.0    239.0    1852.0  ...                  4597.0
# 3                    1846.0    390.0    1775.0  ...                  4785.0
# 4                    1705.0     94.0    1716.0  ...                  4846.0
#
#    Poisonings  Protein  Terrorism (deaths)  Road injuries  \
# 0       512.0   2439.0              1199.0         7425.0
# 1       495.0   2231.0              1092.0         7355.0
# 2       483.0   1998.0              1065.0         7290.0
# 3       483.0   1805.0              1525.0         7432.0
# 4       482.0   1667.0              3521.0         7494.0
#
#    Chronic respiratory diseases  Cirrhosis and other chronic liver diseases  \
# 0                        7222.0                                      3346.0
# 1                        7143.0                                      3316.0
# 2                        7045.0                                      3291.0
# 3                        6916.0                                      3318.0
# 4                        6878.0                                      3353.0
#
#    Digestive diseases  Fire, heat, and hot substances  Acute hepatitis
# 0              6458.0                           481.0           3437.0
# 1              6408.0                           462.0           3005.0
# 2              6358.0                           448.0           2663.0
# 3              6370.0                           448.0           2365.0
# 4              6398.0                           445.0           2264.0
#
# [5 rows x 36 columns]

# %% [markdown]
# Replace NaN with 0s for 'Number of executions...'

# %%
causesofDeath_df_copy = causesofDeath_df_copy.fillna(0)

# %%
causesofDeath_df_copy.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Meningitis  Alzheimer's disease and other dementias  Parkinson's disease  \
# 0      2933.0                                   1402.0                450.0
# 1      2731.0                                   1424.0                455.0
# 2      2460.0                                   1449.0                460.0
# 3      2327.0                                   1508.0                473.0
# 4      2254.0                                   1544.0                482.0
#
#    Nutritional deficiencies  Malaria  Drowning  ...  Chronic kidney disease  \
# 0                    2488.0    393.0    2127.0  ...                  4490.0
# 1                    2277.0    255.0    1973.0  ...                  4534.0
# 2                    2040.0    239.0    1852.0  ...                  4597.0
# 3                    1846.0    390.0    1775.0  ...                  4785.0
# 4                    1705.0     94.0    1716.0  ...                  4846.0
#
#    Poisonings  Protein  Terrorism (deaths)  Road injuries  \
# 0       512.0   2439.0              1199.0         7425.0
# 1       495.0   2231.0              1092.0         7355.0
# 2       483.0   1998.0              1065.0         7290.0
# 3       483.0   1805.0              1525.0         7432.0
# 4       482.0   1667.0              3521.0         7494.0
#
#    Chronic respiratory diseases  Cirrhosis and other chronic liver diseases  \
# 0                        7222.0                                      3346.0
# 1                        7143.0                                      3316.0
# 2                        7045.0                                      3291.0
# 3                        6916.0                                      3318.0
# 4                        6878.0                                      3353.0
#
#    Digestive diseases  Fire, heat, and hot substances  Acute hepatitis
# 0              6458.0                           481.0           3437.0
# 1              6408.0                           462.0           3005.0
# 2              6358.0                           448.0           2663.0
# 3              6370.0                           448.0           2365.0
# 4              6398.0                           445.0           2264.0
#
# [5 rows x 36 columns]

# %% [markdown]
# Create a column for 'Causes' and another for 'Case Count' using `.melt()`

# %%
id_vars = ['Entity', 'Code', 'Year']
value_vars = causesofDeath_df_copy.columns[3:]

causesofDeath_df_copy = pd.melt(causesofDeath_df_copy, id_vars=id_vars, value_vars=value_vars, 
                                var_name='Causes', value_name='Case_Count')

# %%
causesofDeath_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240009 entries, 0 to 240008
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Entity      240009 non-null  object
#  1   Code        240009 non-null  object
#  2   Year        240009 non-null  int64
#  3   Causes      240009 non-null  object
#  4   Case_Count  240009 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 9.2+ MB

# %%
# let's find out the values that made Case_Count an object type
objectType = []

for i in causesofDeath_df_copy.Case_Count:
      try:
            int(i)
      except:
            objectType.append(i)

# %%
set(objectType)
# Out:
# {'>1', '>1000'}

# %%
objectType = ['>1', '>1000']

causesofDeath_df_copy.query('Case_Count in @objectType')
# Out:
#            Entity Code  Year                                        Causes  \
# 1243        China  CHN  2008  Number of executions (Amnesty International)
# 1244        China  CHN  2009  Number of executions (Amnesty International)
# 1245        China  CHN  2010  Number of executions (Amnesty International)
# 1246        China  CHN  2011  Number of executions (Amnesty International)
# 1247        China  CHN  2012  Number of executions (Amnesty International)
# 1248        China  CHN  2013  Number of executions (Amnesty International)
# 1249        China  CHN  2014  Number of executions (Amnesty International)
# 1250        China  CHN  2015  Number of executions (Amnesty International)
# 1251        China  CHN  2016  Number of executions (Amnesty International)
# 3628     Malaysia  MYS  2015  Number of executions (Amnesty International)
# 4494  North Korea  PRK  2013  Number of executions (Amnesty International)
# 4495  North Korea  PRK  2014  Number of executions (Amnesty International)
# 4496  North Korea  PRK  2015  Number of executions (Amnesty International)
# 4497  North Korea  PRK  2016  Number of executions (Amnesty International)
# 5842  South Sudan  SSD  2016  Number of executions (Amnesty International)
# 6889      Vietnam  VNM  2015  Number of executions (Amnesty International)
# 6890      Vietnam  VNM  2016  Number of executions (Amnesty International)
#
#      Case_Count
# 1243      >1000
# 1244      >1000
# 1245      >1000
# 1246      >1000
# 1247      >1000
# 1248      >1000
# 1249      >1000
# 1250      >1000
# 1251      >1000
# 3628         >1
# 4494         >1
# 4495         >1
# 4496         >1
# 4497         >1
# 5842         >1
# 6889         >1
# 6890         >1

# %% [markdown]
# Let's focus on only health-related deaths

# %%
causesofDeath_df_copy.Causes.unique()
# Out:
# array(['Number of executions (Amnesty International)', 'Meningitis',
#        "Alzheimer's disease and other dementias", "Parkinson's disease",
#        'Nutritional deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal violence', 'Maternal disorders', 'HIV/AIDS',
#        'Drug use disorders', 'Tuberculosis', 'Cardiovascular diseases',
#        'Lower respiratory infections', 'Neonatal disorders',
#        'Alcohol use disorders', 'Self', 'Exposure to forces of nature',
#        'Diarrheal diseases', 'Environmental heat and cold exposure',
#        'Neoplasms', 'Conflict and terrorism', 'Diabetes mellitus',
#        'Chronic kidney disease', 'Poisonings', 'Protein',
#        'Terrorism (deaths)', 'Road injuries',
#        'Chronic respiratory diseases',
#        'Cirrhosis and other chronic liver diseases', 'Digestive diseases',
#        'Fire, heat, and hot substances', 'Acute hepatitis'], dtype=object)

# %% [markdown]
# We'll drop deaths by;
# * Executions ['Number of executions (Amnesty International)']
# * Drowning
# * Interpersonal violence
# * Alcohol use disorders
# * Self
# * Exposure to forces of nature
# * Environmental heat and cold exposure
# * Conflict and terrorism
# * Poisonings
# * Terrorism (deaths)
# * Road injuries
# * Fire, heat and hot substances

# %%
dropCauses = ['Number of executions (Amnesty International)', 'Drowning', 'Interpersonal violence','Alcohol use disorders', 
              'Self', 'Exposure to forces of nature', 'Environmental heat and cold exposure', 'Conflict and terrorism', 'Poisonings',
              'Terrorism (deaths)', 'Road injuries', 'Fire, heat, and hot substances']

# %%
dropIndx = causesofDeath_df_copy.query('Causes in @dropCauses').index

len(dropIndx)/len(causesofDeath_df_copy.Causes)
# Out:
# 0.36363636363636365

# %% [markdown]
# The causes we want to drop make up 36.4% of the dataset which is okay

# %%
causesofDeath_df_copy = causesofDeath_df_copy.drop(index=dropIndx)

# %%
causesofDeath_df_copy.query('Causes in @dropCauses')
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Causes, Case_Count]
# Index: []

# %%
causesofDeath_df_copy.shape
# Out:
# (152733, 5)

# %% [markdown]
# Convert 'Case_Count' to integer

# %%
causesofDeath_df_copy['Case_Count'] = causesofDeath_df_copy['Case_Count'].astype('int')

# %% [markdown]
# Convert 'Year' column to datetime

# %%
causesofDeath_df_copy['Year'] = pd.to_datetime(causesofDeath_df_copy.Year, format='%Y')

# %%
causesofDeath_df_copy.isna().sum()
# Out:
# Entity        0
# Code          0
# Year          0
# Causes        0
# Case_Count    0
# dtype: int64

# %%
causesofDeath_df_copy.sample(10)
# Out:
#                        Entity Code       Year  \
# 239292                 Tuvalu  TUV 1994-01-01
# 88196            Burkina Faso  BFA 1992-01-01
# 34076                Portugal  PRT 2004-01-01
# 135699              Palestine  PSE 2008-01-01
# 146720                  China  CHN 1998-01-01
# 234754                Eritrea  ERI 2013-01-01
# 93559                Thailand  THA 2008-01-01
# 89436   European Region (WHO)    0 2005-01-01
# 62634           North America    0 2008-01-01
# 16297               East Asia    0 2017-01-01
#
#                                          Causes  Case_Count
# 239292                          Acute hepatitis           0
# 88196                   Cardiovascular diseases        9580
# 34076                  Nutritional deficiencies         118
# 135699                       Diarrheal diseases          53
# 146720                                Neoplasms     1736175
# 234754                          Acute hepatitis         117
# 93559                   Cardiovascular diseases       86876
# 89436                   Cardiovascular diseases     4474524
# 62634                        Maternal disorders           0
# 16297   Alzheimer's disease and other dementias           0

# %% [markdown]
# #### `ageGroupDeaths_df`
# * ~~Create a subset of only African countries~~
# * Create a column for 'Age Range' and another for 'Death Count' using `.melt()`

# %%
ageGroupDeaths_df.shape
# Out:
# (6840, 8)

# %%
ageGroupDeaths_df_copy.head()
# Out:
#         Entity Code  Year  Deaths 70+ years  Deaths 50-69 years  \
# 0  Afghanistan  AFG  1990             34681               40624
# 1  Afghanistan  AFG  1991             35271               41414
# 2  Afghanistan  AFG  1992             35694               41829
# 3  Afghanistan  AFG  1993             36433               42598
# 4  Afghanistan  AFG  1994             37460               43923
#
#    Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 0                    22968               5642           78170
# 1                    26523               6433           83035
# 2                    30000               6854           93859
# 3                    32339               7206          106537
# 4                    36817               8106          115334

# %% [markdown]
# Creating subset of only African countries

# %%
#ageGroupDeaths_df_copy = ageGroupDeaths_df_copy.query('Code in @african_three_letter_code')

# %%
ageGroupDeaths_df_copy.shape
# Out:
# (6840, 8)

# %%
ageGroupDeaths_df_copy.Entity.sample(10)
# Out:
# 2401                             Guatemala
# 4051                           New Zealand
# 1871                               Estonia
# 934                               Cambodia
# 2675                             Indonesia
# 4802          Region of the Americas (WHO)
# 1678    Eastern Mediterranean Region (WHO)
# 3934                               Namibia
# 2553                              Honduras
# 5692                                 Sudan
# Name: Entity, dtype: object

# %% [markdown]
# Create a column for 'Age Range' and another for 'Death Count' using `.melt()`

# %%
id_vars = ['Entity', 'Code', 'Year']
value_vars = ageGroupDeaths_df_copy.columns[3:]

ageGroupDeaths_df_copy = pd.melt(ageGroupDeaths_df_copy, id_vars=id_vars, value_vars=value_vars, 
                                 var_name='Age_Group', value_name='Death_Count')

# %%
ageGroupDeaths_df_copy.shape
# Out:
# (34200, 5)

# %%
ageGroupDeaths_df_copy['Age_Group'].unique()
# Out:
# array(['Deaths 70+ years', 'Deaths 50-69 years',
#        'Deaths Age: 15-49 years', 'Deaths 5-14 years', 'Deaths Under 5'],
#       dtype=object)

# %% [markdown]
# Let's remove the 'Deaths' from the values in 'Age_Group'

# %%
ageGroupDeaths_df_copy['Age_Group'] = ageGroupDeaths_df_copy['Age_Group'].str.replace('Deaths ', '')
ageGroupDeaths_df_copy['Age_Group'] = ageGroupDeaths_df_copy['Age_Group'].str.replace('Age: ', '')

# %%
ageGroupDeaths_df_copy['Age_Group'].unique()
# Out:
# array(['70+ years', '50-69 years', '15-49 years', '5-14 years', 'Under 5'],
#       dtype=object)

# %% [markdown]
# Convert 'Year' to datetime

# %%
ageGroupDeaths_df_copy['Year'] = pd.to_datetime(ageGroupDeaths_df_copy.Year, format='%Y')

# %%
ageGroupDeaths_df_copy.sample(10)
# Out:
#                                    Entity Code       Year    Age_Group  \
# 10659                          Montenegro  MNE 1999-01-01  50-69 years
# 5073                Sao Tome and Principe  STP 1993-01-01    70+ years
# 1674   Eastern Mediterranean Region (WHO)  NaN 2014-01-01    70+ years
# 24112                          Mauritania  MRT 2012-01-01   5-14 years
# 31109                             Moldova  MDA 2019-01-01      Under 5
# 7959                                Chile  CHL 1999-01-01  50-69 years
# 4540                               Panama  PAN 2000-01-01    70+ years
# 17604                             Myanmar  MMR 2014-01-01  15-49 years
# 26134                           Sri Lanka  LKA 1994-01-01   5-14 years
# 20796                             Armenia  ARM 1996-01-01   5-14 years
#
#        Death_Count
# 10659         1715
# 5073           291
# 1674       1185851
# 24112          762
# 31109          399
# 7959         20978
# 4540          5786
# 17604        76977
# 26134         1984
# 20796          224

# %% [markdown]
# #### `doctorsPerPopulation_df`
# * ~~Create subset of only African countries~~

# %%
doctorsPerPopulation_df_copy.sample(5)
# Out:
#      IndicatorCode                                     Indicator  \
# 9533      HWF_0005  Medical doctors not further defined (number)
# 6094      HWF_0002                      Medical doctors (number)
# 9391      HWF_0005  Medical doctors not further defined (number)
# 5646      HWF_0002                      Medical doctors (number)
# 1125      HWF_0001                  Medical doctors (per 10,000)
#
#      ParentLocationCode         ParentLocation ThreeLocCode  \
# 9533                EMR  Eastern Mediterranean          PAK
# 6094                WPR        Western Pacific          MYS
# 9391                EMR  Eastern Mediterranean          ARE
# 5646                EUR                 Europe          TUR
# 1125                EUR                 Europe          AZE
#
#                   Location  Period  FactValueNumeric   Value
# 9533              Pakistan    1992          60042.00  60 042
# 6094              Malaysia    2009          30536.00  30 536
# 9391  United Arab Emirates    2004           7802.00    7802
# 5646               Türkiye    1995          67828.00  67 828
# 1125            Azerbaijan    2004             35.57   35.57

# %%
doctorsPerPopulation_df_copy.shape
# Out:
# (11508, 9)

# %%
#doctorsPerPopulation_df_copy = doctorsPerPopulation_df_copy.query('ThreeLocCode in @african_three_letter_code')

# %%
doctorsPerPopulation_df_copy.shape
# Out:
# (11508, 9)

# %% [markdown]
# Let's remove the whitespace characters in 'Value'

# %%
doctorsPerPopulation_df_copy['Value'] = doctorsPerPopulation_df_copy.Value.str.replace('\xa0', '')

# %%
objectType = []

for i in doctorsPerPopulation_df_copy.Value:
      try:
            float(i)
      except:
            objectType.append(i)

# %%
set(objectType)
# Out:
# set()

# %% [markdown]
# Change the column 'Period' to 'Year' then convert to datetime.

# %%
doctorsPerPopulation_df_copy.rename(columns={'Period':'Year'}, inplace=True)

doctorsPerPopulation_df_copy['Year'] = pd.to_datetime(doctorsPerPopulation_df_copy.Year, format='%Y')

# %%
doctorsPerPopulation_df_copy.sample(15)
# Out:
#       IndicatorCode                                     Indicator  \
# 9382       HWF_0005  Medical doctors not further defined (number)
# 4283       HWF_0002                      Medical doctors (number)
# 3342       HWF_0002                      Medical doctors (number)
# 10145      HWF_0005  Medical doctors not further defined (number)
# 115        HWF_0001                  Medical doctors (per 10,000)
# 4121       HWF_0002                      Medical doctors (number)
# 3868       HWF_0002                      Medical doctors (number)
# 10313      HWF_0005  Medical doctors not further defined (number)
# 2368       HWF_0001                  Medical doctors (per 10,000)
# 7159       HWF_0003     Generalist medical practitioners (number)
# 11335      HWF_0005  Medical doctors not further defined (number)
# 7283       HWF_0003     Generalist medical practitioners (number)
# 1080       HWF_0001                  Medical doctors (per 10,000)
# 8590       HWF_0004     Specialist medical practitioners (number)
# 3076       HWF_0002                      Medical doctors (number)
#
#       ParentLocationCode         ParentLocation ThreeLocCode  \
# 9382                 EMR  Eastern Mediterranean          ARE
# 4283                 EUR                 Europe          CZE
# 3342                 AMR               Americas          COL
# 10145                EUR                 Europe          FIN
# 115                  AFR                 Africa          ERI
# 4121                 EUR                 Europe          BIH
# 3868                 EMR  Eastern Mediterranean          TUN
# 10313                EUR                 Europe          HUN
# 2368                 EUR                 Europe          UZB
# 7159                 EUR                 Europe          MNE
# 11335                WPR        Western Pacific          MNG
# 7283                 EUR                 Europe          SRB
# 1080                 EUR                 Europe          AUT
# 8590                 EUR                 Europe          TUR
# 3076                 AFR                 Africa          MOZ
#
#                      Location       Year  FactValueNumeric  Value
# 9382     United Arab Emirates 2013-01-01          16016.00  16016
# 4283                  Czechia 1987-01-01          27145.00  27145
# 3342                 Colombia 2004-01-01          57774.00  57774
# 10145                 Finland 1999-01-01          12401.00  12401
# 115                   Eritrea 2005-01-01              0.43   0.43
# 4121   Bosnia and Herzegovina 2004-01-01           5680.00   5680
# 3868                  Tunisia 2016-01-01          14507.00  14507
# 10313                 Hungary 1985-01-01          27978.00  27978
# 2368               Uzbekistan 2004-01-01             27.21  27.21
# 7159               Montenegro 2010-01-01            195.00    195
# 11335                Mongolia 2011-01-01           7943.00   7943
# 7283                   Serbia 2013-01-01           6480.00   6480
# 1080                  Austria 2019-01-01             52.73  52.73
# 8590                  Türkiye 1989-01-01          23750.00  23750
# 3076               Mozambique 2017-01-01           2180.00   2180

# %% [markdown]
# Since the 'FactValueNumeric' and the 'Value' column are the same, let's drop the 'Value' column.

# %%
doctorsPerPopulation_df_copy = doctorsPerPopulation_df_copy.drop('Value', axis=1)

# %% [markdown]
# Replace wrong country names in Locations

# %%
doctorsCountry = doctorsPerPopulation_df_copy.query('ParentLocation == "Africa" & Indicator == "Medical doctors (per 10,000)"').Location.unique()

# %%
set(africanCountries.Country_Name).difference(set(doctorsCountry))
# Out:
# {'Cape Verde',
#  "Cote d'Ivoire",
#  'Democratic Republic of Congo',
#  'Djibouti',
#  'Egypt',
#  'Libyan Arab Jamahiriya',
#  'Mayotte',
#  'Morocco',
#  'Reunion',
#  'Saint Helena',
#  'Somalia',
#  'Sudan',
#  'Swaziland',
#  'Tanzania',
#  'Tunisia',
#  'Western Sahara'}

# %%
set(doctorsCountry).difference(set(list(africanCountries.Country_Name)))
# Out:
# {'Cabo Verde',
#  'Côte d’Ivoire',
#  'Democratic Republic of the Congo',
#  'Eswatini',
#  'United Republic of Tanzania'}

# %%
# values to replace
curVals = ['Cabo Verde', 'Côte d’Ivoire', 'Democratic Republic of the Congo', 'Eswatini', 'United Republic of Tanzania']
# values we're to replace with
toRepVals = ['Cape Verde', "Cote d'Ivoire", 'Democratic Republic of Congo', 'Swaziland', 'Tanzania']

for i in range(len(curVals)):
      doctorsPerPopulation_df_copy['Location'] = doctorsPerPopulation_df_copy.Location.str.replace(pat=curVals[i], repl=toRepVals[i], regex=False)

# %%
# check
doctorsCountry = doctorsPerPopulation_df_copy.query('ParentLocation == "Africa" & Indicator == "Medical doctors (per 10,000)"').Location.unique()
set(doctorsCountry).difference(set(list(africanCountries.Country_Name)))
# Out:
# set()

# %% [markdown]
# #### `healthExpenditure`
# * ~~Create subset of African countries~~
# * Drop 'Indicator Name'
# * Create a column for 'Year' and 'Health Expenditure (% of GDP)' for values using `.melt()`

# %%
healthExpenditure_copy.sample(5)
# Out:
#                   Country Name Country Code  \
# 126                Korea, Rep.          KOR
# 248                    Ukraine          UKR
# 225  Sint Maarten (Dutch part)          SXM
# 250                    Uruguay          URY
# 79       Micronesia, Fed. Sts.          FSM
#
#                             Indicator Name      2000      2001      2002  \
# 126  Current health expenditure (% of GDP)  3.897594  4.427623  4.164910
# 248  Current health expenditure (% of GDP)  5.306852  5.725344  5.992200
# 225  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 250  Current health expenditure (% of GDP)  9.210958  9.798644  9.681342
# 79   Current health expenditure (% of GDP)  7.765111  8.452600  7.897204
#
#          2003       2004       2005       2006  ...       2012       2013  \
# 126  4.423874   4.388965   4.617822   4.943968  ...   6.132620   6.247894
# 248  6.545741   6.168570   6.346158   6.416952  ...   7.116655   6.941553
# 225       NaN        NaN        NaN        NaN  ...        NaN        NaN
# 250  9.617535   8.301454   7.756861   7.742874  ...   8.067562   8.118961
# 79   9.571505  12.027157  17.733067  10.741291  ...  12.277098  12.138487
#
#           2014       2015       2016       2017       2018       2019  2020  \
# 126   6.474381   6.652717   6.914327   7.106949   7.543884   8.164165   NaN
# 248   7.189581   7.776093   7.545402   7.433325   7.519885   7.098602   NaN
# 225        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 250   8.073218   8.292236   8.675338   8.821792   9.014555   9.347832   NaN
# 79   11.732163  12.456488  13.139224  12.214388  11.703626  11.442080   NaN
#
#      2021
# 126   NaN
# 248   NaN
# 225   NaN
# 250   NaN
# 79    NaN
#
# [5 rows x 25 columns]

# %%
healthExpenditure_copy.shape
# Out:
# (266, 25)

# %% [markdown]
# Create subset of African countries

# %%
# change Country Code column name
healthExpenditure_copy.rename(columns={'Country Code':'Country_Code'}, inplace=True)
#healthExpenditure_copy = healthExpenditure_copy.query('Country_Code in @african_three_letter_code')

# %% [markdown]
# Create a column for 'Year' and 'Health Expenditure (% of GDP)' for values using `.melt()` and drop 'Indicator Name'

# %%
id_vars = ['Country Name', 'Country_Code']
value_vars = healthExpenditure_copy.columns[3:]

healthExpenditure_copy = pd.melt(healthExpenditure_copy, id_vars=id_vars, value_vars=value_vars, 
                                 var_name='Year', value_name='Health Expenditure (% of GDP)')

# %% [markdown]
# Convert 'Year' column to datetime

# %%
healthExpenditure_copy['Year'] = pd.to_datetime(healthExpenditure_copy.Year, format='%Y')

# %%
healthExpenditure_copy.shape
# Out:
# (5852, 4)

# %%
healthExpenditure_copy.sample(10)
# Out:
#                                     Country Name Country_Code       Year  \
# 198                    Post-demographic dividend          PST 2000-01-01
# 85                                        Guinea          GIN 2000-01-01
# 3008                                     Georgia          GEO 2011-01-01
# 5674                           Equatorial Guinea          GNQ 2021-01-01
# 87                                 Guinea-Bissau          GNB 2000-01-01
# 5003  Sub-Saharan Africa (excluding high income)          SSA 2018-01-01
# 1925                         East Asia & Pacific          EAS 2007-01-01
# 1845                         Upper middle income          UMC 2006-01-01
# 3411                       Sao Tome and Principe          STP 2012-01-01
# 2760                                       Haiti          HTI 2010-01-01
#
#       Health Expenditure (% of GDP)
# 198                        9.572835
# 85                         4.745677
# 3008                       8.014443
# 5674                            NaN
# 87                         6.744849
# 5003                       5.039467
# 1925                       5.745081
# 1845                       5.260827
# 3411                       6.476295
# 2760                       4.625833

# %% [markdown]
# Replace wrong 'Country Name's

# %%
set(africanCountries.Country_Name).difference(set(healthExpenditure_copy.query('Country_Code in @africanCountries.Three_Letter_Country_Code')['Country Name']))
# Out:
# {'Cape Verde',
#  'Congo',
#  'Democratic Republic of Congo',
#  'Egypt',
#  'Gambia',
#  'Libyan Arab Jamahiriya',
#  'Mayotte',
#  'Reunion',
#  'Saint Helena',
#  'Swaziland',
#  'Western Sahara'}

# %%
set(healthExpenditure_copy.query('Country_Code in @africanCountries.Three_Letter_Country_Code')['Country Name']).difference(set(africanCountries.Country_Name))
# Out:
# {'Cabo Verde',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Egypt, Arab Rep.',
#  'Eswatini',
#  'Gambia, The',
#  'Libya'}

# %%
# values to replace
curVals = ['Cabo Verde', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Egypt, Arab Rep.', 'Eswatini', 'Gambia, The', 'Libya']
# values we're to replace with
toRepVals = ['Cape Verde', 'Democratic Republic of Congo', 'Congo', 'Egypt', 'Swaziland', 'Gambia', 'Libyan Arab Jamahiriya']

for i in range(len(curVals)):
      healthExpenditure_copy['Country Name'] = healthExpenditure_copy['Country Name'].str.replace(pat=curVals[i], repl=toRepVals[i], regex=False)

# %%
set(healthExpenditure_copy.query('Country_Code in @africanCountries.Three_Letter_Country_Code')['Country Name']).difference(set(africanCountries.Country_Name))
# Out:
# set()

# %% [markdown]
# ### Storing data

# %%
# We then group the dataframes into a list for more efficient processing 
dflist = [countryCodes_df_copy, causesofDeath_df_copy, ageGroupDeaths_df_copy,
          doctorsPerPopulation_df_copy, healthExpenditure_copy, africanCountries]
sheetname = ['World_Countries', 'Causes_of_Death', 'Death_by_Age_Group',
             'Doctors_per_Population', 'Health_Expenditure', 'African_Countries']

# We'll define an Excel writer object and the target file
Excelwriter = pd.ExcelWriter("./data/World Healthcaredata.xlsx",engine="xlsxwriter")

#We now we'll loop the list of dataframes
for i, df in enumerate (dflist):
    df.to_excel(Excelwriter, sheet_name=sheetname[i],index=False)
#And finally we save the file
Excelwriter.save()
